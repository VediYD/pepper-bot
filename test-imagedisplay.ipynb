# %%
from naoqi import qi
from time import time, sleep

# %%
ip, port = '10.104.23.185', '9559'

# %%
session = qi.Session()
session.connect("tcp://" + ip + ":" + port)

# %%
tabletService = session.service("ALTabletService")

# %%
tabletService.loadUrl("http://198.18.0.1/page.html")
# Out:
# True

# %%
tabletService.showWebview()
# Out:
# True

# %%
tabletService.hideWebview()
# Out:
# True

# %%
tabletService.loadApplication("")

# %%
dir(tabletService)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cancelReset',
#  '_clearWebviewCache',
#  '_crash',
#  '_displayToast',
#  '_enableResetTablet',
#  '_firmwareVersion',
#  '_getApkVersion',
#  '_getApkVersionCode',
#  '_getAutoDateTimeEnabled',
#  '_getTabletModelName',
#  '_getTabletSerialno',
#  '_installApk',
#  '_installSystemApk',
#  '_isApkExist',
#  '_isTopActivity',
#  '_isTopApp',
#  '_launchApk',
#  '_launcherVersion',
#  '_listApks',
#  '_openSettings',
#  '_ping',
#  '_powerOff',
#  '_purgeInstallTabletUpdater',
#  '_removeApk',
#  '_restart',
#  '_setAnimatedCrossWalkView',
#  '_setAutoDateTimeEnabled',
#  '_setBlackScreenMode',
#  '_setDebugCrossWalkViewEnable',
#  '_setDebugEnabled',
#  '_setLifeDetectorEnabled',
# ...

# %%
posture_service = session.service("ALRobotPosture")

# %%
posture_service.getPostureFamily()
# Out:
# 'Standing'

# %%
posture_service.applyPosture('Stand', 1)
# Out:
# True

# %%
posture_service.getPostureList()
# Out:
# ['Crouch', 'Stand', 'StandInit', 'StandZero']

# %%
app = qi.Application()
app.session.connect("tcp://" + ip + ":" + port)

# %%
almemory = app.session.service("ALMemory")

# %%
qi.path.dataPaths(app)
# Out:
# ArgumentErrorTraceback (most recent call last)
# <ipython-input-13-8617971d305c> in <module>()
# ----> 1 qi.path.dataPaths(app)
#
# ArgumentError: Python argument types in
#     _qi.dataPaths(ApplicationSession)
# did not match C++ signature:
#     dataPaths(void)
#     dataPaths(std::string)

# %%
session = qi.Session()
session.connect("tcp://" + ip + ":" + port)

# %%
behaviorManager = session.service("ALBehaviorManager")

# %%
dir(behaviorManager)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__pCall',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_getBehaviorFrameManagerId',
#  '_getBehaviorRelativePath',
#  '_getPackageUid',
#  '_onDataChanged',
#  'addDefaultBehavior',
#  'async',
#  'behaviorFailed',
#  'behaviorLoaded',
#  'behaviorStarted',
#  'behaviorStopped',
#  'behaviorsAdded',
#  'behaviorsRemoved',
#  'call',
#  'exit',
#  'getBehaviorNames',
#  'getBehaviorNature',
#  'getBehaviorTags',
#  'getBehaviorsByTag',
#  'getBrokerName',
#  'getDefaultBehaviors',
#  'getInstalledBehaviors',
#  'getLoadedBehaviors',
#  'getMethodHelp',
#  'getMethodList',
#  'getModuleHelp',
#  'getRunningBehaviors',
#  'getSystemBehaviorNames',
#  'getTagList',
#  'getUsage',
#  'getUserBehaviorNames',
# ...

# %%
behaviorManager.getUserBehaviorNames()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-9-fec0aec0aad0> in <module>()
# ----> 1 behaviorManager.getUserBehaviorNames()
#
# NameError: name 'behaviorManager' is not defined

# %%
behaviorManager.startBehavior("User/.lastUploadedChoregrapheBehavior/behavior_1")

# %%
behaviorManager.runBehavior("User/.lastUploadedChoregrapheBehavior/behavior_1")

# %%
behaviorManager.preloadBehavior("User/.lastUploadedChoregrapheBehavior/behavior_1")
# Out:
# True

# %%
behaviorManager.removeDefaultBehavior("User/.lastUploadedChoregrapheBehavior/behavior_1")

# %%
behaviorManager.behaviorsAdded()

# %%
sys = session.service("ALSystem")

# %%
sys.reboot()

# %%
sys.shutdown()

# %%
help(behaviorManager.pCall)
# Out:
# Help on built-in function <unnamed Boost.Python function> in <unnamed Boost:
#
# <unnamed Boost.Python function>(...)
#     Signature: m
#     NAOqi1 pCall method.

# %%
behaviorManager.metaObject()
# Out:
# {'description': 'This module is intended to manage behaviors. With this module, you can load, start, stop behaviors, add default behaviors or remove them. \n',
#  'methods': {0L: {'description': '',
#    'name': 'registerEvent',
#    'parameters': [],
#    'parametersSignature': '(IIL)',
#    'returnDescription': '',
#    'returnSignature': 'L',
#    'uid': 0L},
#   1L: {'description': '',
#    'name': 'unregisterEvent',
#    'parameters': [],
#    'parametersSignature': '(IIL)',
#    'returnDescription': '',
#    'returnSignature': 'v',
#    'uid': 1L},
#   2L: {'description': '',
#    'name': 'metaObject',
#    'parameters': [],
#    'parametersSignature': '(I)',
#    'returnDescription': '',
# ...

# %%
tabletService = session.service("ALTabletService")
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-19-f5cee25cdc23> in <module>()
# ----> 1 tabletService = session.service("ALTabletService")
#
# RuntimeError: Session not connected.

# %%
dir(tabletService)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cancelReset',
#  '_clearWebviewCache',
#  '_crash',
#  '_displayToast',
#  '_enableResetTablet',
#  '_firmwareVersion',
#  '_getApkVersion',
#  '_getApkVersionCode',
#  '_getAutoDateTimeEnabled',
#  '_getTabletModelName',
#  '_getTabletSerialno',
#  '_installApk',
#  '_installSystemApk',
#  '_isApkExist',
#  '_isTopActivity',
#  '_isTopApp',
#  '_launchApk',
#  '_launcherVersion',
#  '_listApks',
#  '_openSettings',
#  '_ping',
#  '_powerOff',
#  '_purgeInstallTabletUpdater',
#  '_removeApk',
#  '_restart',
#  '_setAnimatedCrossWalkView',
#  '_setAutoDateTimeEnabled',
#  '_setBlackScreenMode',
#  '_setDebugCrossWalkViewEnable',
#  '_setDebugEnabled',
#  '_setLifeDetectorEnabled',
# ...

# %%
tabletService.getWifiStatus()
# Out:
# 'DISCONNECTED'

# %%
tabletService.enableWifi()

# %%
tabletService.getWifiStatus()
# Out:
# 'DISCONNECTED'

# %%
resourceManager = session.service("ALResourceManager")
resourceManager.getResources()
# Out:
# [[['Standing', 'Sitting', 'Sitting on chair', 'Crouching'],
#   [['HeadYaw', 'HeadPitch'],
#    [['LShoulderPitch',
#      'LShoulderRoll',
#      'LElbowRoll',
#      'LElbowYaw',
#      'LWristYaw',
#      'LHand'],
#     ['RShoulderPitch',
#      'RShoulderRoll',
#      'RElbowRoll',
#      'RElbowYaw',
#      'RWristYaw',
#      'RHand']],
#    ['LHipYawPitch',
#     ['LHipPitch', 'LHipRoll', 'LKneePitch', 'LAnklePitch', 'LAnkleRoll'],
#     ['RHipPitch', 'RHipRoll', 'RKneePitch', 'RAnklePitch', 'RAnkleRoll']]],
#   ['Left eye leds',
#    'Right eye leds',
#    'Left ear leds',
#    'Right ear leds',
#    'Chest leds',
#    'Head leds',
#    'Left foot leds',
#    'Right foot leds'],
#   ['Head-sequence', 'Left arm-sequence', 'Right arm-sequence'],
#   'Camera setting',
#   [['Speech', 'Audio player'], ['Speech recognition', 'Audio recorder']],
#   ['Head-stiffness', 'Arms-stiffness', 'Legs-stiffness'],
#   ['Standing',
#    [['LShoulderPitch',
#      'LShoulderRoll',
# ...

# %%
tabletService.loadUrl("http://198.18.0.1/page.html")
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-18-ed582c176bdd> in <module>()
# ----> 1 tabletService.loadUrl("http://198.18.0.1/page.html")
#
# RuntimeError: Socket is not connected

# %%
dir(tabletService)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cancelReset',
#  '_clearWebviewCache',
#  '_crash',
#  '_displayToast',
#  '_enableResetTablet',
#  '_firmwareVersion',
#  '_getApkVersion',
#  '_getApkVersionCode',
#  '_getAutoDateTimeEnabled',
#  '_getTabletModelName',
#  '_getTabletSerialno',
#  '_installApk',
#  '_installSystemApk',
#  '_isApkExist',
#  '_isTopActivity',
#  '_isTopApp',
#  '_launchApk',
#  '_launcherVersion',
#  '_listApks',
#  '_openSettings',
#  '_ping',
#  '_powerOff',
#  '_purgeInstallTabletUpdater',
#  '_removeApk',
#  '_restart',
#  '_setAnimatedCrossWalkView',
#  '_setAutoDateTimeEnabled',
#  '_setBlackScreenMode',
#  '_setDebugCrossWalkViewEnable',
#  '_setDebugEnabled',
#  '_setLifeDetectorEnabled',
# ...

# %%
tabletService.showWebview()
# Out:
# True
