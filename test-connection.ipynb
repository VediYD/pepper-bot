# %%
from naoqi import ALProxy


IP = "192.168.0.192"
tts = ALProxy("ALTextToSpeech", IP, 9559)
tts.say('The test is successful. You have connected to me using the Python API.')

# %%
from naoqi import ALProxy
import time

ip = "192.168.0.192"
port = 9559
speech_proxy = ALProxy("ALTextToSpeech", ip, port)
speech_recognition_proxy = ALProxy("ALSpeechRecognition", ip, port)
memory_proxy = ALProxy("ALMemory", ip, port)

speech_recognition_proxy.setLanguage("English")
# speech_recognition_proxy.setVisualExpression(True)
# Record on saying "Pepper"
speech_recognition_proxy.pause(True)
speech_recognition_proxy.unsubscribe()
speech_recognition_proxy.setVocabulary(["Pepper"], False)
speech_recognition_proxy.subscribe("Test_ASR")
time.sleep(10)
speech_recognition_proxy.unsubscribe("Test_ASR")

# Get the recognized words and confidence levels
recognized_words = memory_proxy.getData("WordRecognized")
print(recognized_words)
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-3-328604e7fff5> in <module>()
#      12 # Record on saying "Pepper"
#      13 speech_recognition_proxy.pause(True)
# ---> 14 speech_recognition_proxy.unsubscribe()
#      15 speech_recognition_proxy.setVocabulary(["Pepper"], False)
#      16 speech_recognition_proxy.subscribe("Test_ASR")
#
# /pynaoqi-python2.7-2.5.7.1-linux64/lib/python2.7/site-packages/naoqi.py in __call__(self, *args, **kwargs)
#     192                     self.__method__ = method
#     193                 def __call__(self, *args, **kwargs):
# --> 194                     return self.__wrapped__.method_missing(self.__method__, *args, **kwargs)
#     195
#     196             return MethodMissing(self, attr)
#
# /pynaoqi-python2.7-2.5.7.1-linux64/lib/python2.7/site-packages/naoqi.py in method_missing(self, method, *args, **kwargs)
#     262                 result = self.pythonCall(list)
#     263           except RuntimeError,e:
# ...
